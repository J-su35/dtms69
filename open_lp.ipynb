# %%
import pandas as pd

# %%
parquet_path_1 = "D:\dtms69\dtms\LP_parquet\LP_oct2026.parquet"

# %%
df_oct = pd.read_parquet(parquet_path_1, engine='pyarrow')
df_oct
# Out:
#            PEA_No    KWH  kW average   AA   AB   AC  kW exp average Finergy  \
# 0      6200022544  0.007       0.028  0.0  0.0  0.0             0.0   false
# 1      6200022544  0.007       0.028  0.0  0.0  0.0             0.0   false
# 2      6200022544  0.007       0.028  0.0  0.0  0.0             0.0   false
# 3      6200022544  0.006       0.024  0.0  0.0  0.0             0.0   false
# 4      6200022544  0.007       0.028  0.0  0.0  0.0             0.0   false
# ...           ...    ...         ...  ...  ...  ...             ...     ...
# 59515  6200118626  0.002       0.008  0.0  0.0  0.0             0.0   false
# 59516  6200118626  0.015       0.060  0.0  0.0  0.0             0.0   false
# 59517  6200118626  0.014       0.056  0.0  0.0  0.0             0.0   false
# 59518  6200118626  0.014       0.056  0.0  0.0  0.0             0.0   false
# 59519  6200118626  0.009       0.036  0.0  0.0  0.0             0.0   false
#
#       Phase
# 0         A
# 1         A
# 2         A
# ...
